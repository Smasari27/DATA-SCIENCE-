# %%
import pandas as pd

# %%
df = pd.read_csv("anime_data.csv")

# %%
df.head()
# Out:
#    anime_id                                              title anime_type  \
# 0     51818                    Enen no Shouboutai: San no Shou         TV
# 1     56038                                            Lazarus         TV
# 2     59160                              Wind Breaker Season 2         TV
# 3     59597                                        Witch Watch         TV
# 4     60146  Saikyou no Ousama, Nidome no Jinsei wa Nani wo...         TV
#
#       source  episodes            status                 aired_string  \
# 0      Manga        12  Currently Airing  Apr 5, 2025 to Jun 21, 2025
# 1   Original        13  Currently Airing             Apr 6, 2025 to ?
# 2  Web manga        12  Currently Airing  Apr 4, 2025 to Jun 20, 2025
# 3      Manga        26  Currently Airing             Apr 6, 2025 to ?
# 4      Other        12  Currently Airing  Apr 2, 2025 to Jun 18, 2025
#
#                            rating  score   rank  popularity  members  \
# ...

# %%
df.columns
# Out:
# Index(['anime_id', 'title', 'anime_type', 'source', 'episodes', 'status',
#        'aired_string', 'rating', 'score', 'rank', 'popularity', 'members',
#        'favorites', 'scored_by', 'duration_min', 'studios', 'genres',
#        'producers', 'synopsis'],
#       dtype='str')

# %%
df.describe()
# Out:
#            anime_id     episodes        score          rank    popularity  \
# count   7739.000000  7739.000000  7739.000000   7739.000000   7739.000000
# mean   33172.386484    41.675539     5.433464   7722.623336   8305.822458
# std    20118.109319   137.860548     3.002387   6438.090930   7506.126484
# min       15.000000     0.000000     0.000000      0.000000      1.000000
# 25%    11740.000000    11.000000     5.480000   2098.000000   1894.500000
# 50%    36531.000000    13.000000     6.630000   6149.000000   5637.000000
# 75%    51386.500000    26.000000     7.420000  12247.500000  14077.000000
# max    61764.000000  1818.000000     9.300000  21707.000000  28442.000000
#
#             members      favorites     scored_by  duration_min
# count  7.739000e+03    7739.000000  7.739000e+03   7739.000000
# mean   1.829002e+05    5004.539992  9.710739e+04     17.658095
# std    4.564634e+05   25995.257733  2.749953e+05      9.169277
# ...

# %%
df.describe(include = "all")
# Out:
#             anime_id      title anime_type source     episodes  \
# count    7739.000000       7739       7739   7739  7739.000000
# unique           NaN       5142          6     17          NaN
# top              NaN  One Piece         TV  Manga          NaN
# freq             NaN         64       6600   2368          NaN
# mean    33172.386484        NaN        NaN    NaN    41.675539
# std     20118.109319        NaN        NaN    NaN   137.860548
# min        15.000000        NaN        NaN    NaN     0.000000
# 25%     11740.000000        NaN        NaN    NaN    11.000000
# 50%     36531.000000        NaN        NaN    NaN    13.000000
# 75%     51386.500000        NaN        NaN    NaN    26.000000
# max     61764.000000        NaN        NaN    NaN  1818.000000
#
#                  status       aired_string                     rating  \
# count              7739               7739                       7664
# ...

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
